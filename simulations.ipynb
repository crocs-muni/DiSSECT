# %%
load("./curve_handler.sage")

#hex string to binary string
def sha1_bin(x):
    return format(ZZ(hashlib.sha1(bytes.fromhex(x)).hexdigest(), 16), '0160b')

def sha1_hex(x):
    return format(ZZ(sha1(x), 2), '0160x')

def int_to_hex_string(x):
    f = '0' + str(ceil(x.nbits()/8)*2) + 'X'
    return format(ZZ(x, 16), f)

def increment_seed(seed, i = 1):
    '''accepts a hex string as input (not starting with 0x)'''
    g = ZZ(seed, 16).nbits()
    f = '0' + str(len(seed)) + 'X'
    return format(ZZ(Mod(ZZ(seed, 16) + i, 2^g)), f)

#http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.202.2977&rep=rep1&type=pdf, page 42
def generate_r(seed, p):
    t = p.nbits()
#     t = ceil(log(p,2))
#     originally floor
    s = floor((t-1)/160)
    h = t - 160 * s
#     print("t:",t, "s:", s, "h:", h)
    H = sha1_bin(seed)
    c0  = H[-h:]
    c0_modified = list(c0)
    c0_modified[0] = '0'
    W = [0] * (s + 1)
    W[0] =  ''.join(c0_modified)
    for i in [1..s]:
        input_i = increment_seed(seed, i)
        W[i] = sha1_bin(input_i)
    W_joint = ''.join(W)
    assert(len(W_joint) == t)
    r = 0
    for i in [1..t]:
        r += ZZ(W_joint[i-1]) * 2^(t-i)
    assert(r == ZZ(W_joint, 2))
    F = GF(p)
    return F(r)

def expected_r(p, a, b):
    F = GF(p)
    return F(a^3/b^2)

def verify_r(p, r, a, b):
    F = GF(p)
    return F(r) == expected_r(p, a, b)

def get_b_from_r(r, p, a = -3):
    F = GF(p)
    if F(a^3/r).is_square():
        return ZZ(F(a^3/r).sqrt())
    else:
        return None

def millerrabinliar(n,a):
    r = 0
    m = n-1
    while m % 2 == 0:
        r += 1
        m = m/2
    if Mod(a,n)^m == Mod(1,n):
        return True
    for i in range(r):
        if Mod(a,n)^(m*2^i) == Mod(-1,n):
            return True
    return False

def millerrabin(n):
    for a in prime_range(200):
        if not millerrabinliar(n, a):
            return False
    return True

# A2.2 in http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.202.2977&rep=rep1&type=pdf
def verify_near_primality(u, r_min, l_max = 255, MR = True):
    n = u
    h = 1
    for l in prime_range(l_max):
        while n % l == 0:
            n = ZZ(n / l)
            h = h * l
            if n < r_min:
                return (False, None, None)
    if MR and millerrabin(n):
        return (True, h, n)
    elif is_pseudoprime(n):
        return (True, h, n)
    return (False, None, None)

def verify_security(E, r_min_bits = 160, B = 20, MR = True, verbose = False):
    if verbose:
        print("Computing order")
    q = E.base_field().order()
    r_min = max(2^r_min_bits, 4 * sqrt(q))
    o = E.order()
    if verbose:
        print("Checking near-primality of", o)
    alright, h, n = verify_near_primality(o, r_min, MR = MR)
    if not alright:
        return (False, None, None)
    if verbose:
        print("Checking MOV")
    if embedding_degree(E, o) < B:
        return (False, None, None)
    if verbose:
        print("Checking Frob")
    if E.trace_of_frobenius() in [-1, 1]:
        return (False, None, None)
    return (True, h, n)

def generate_x962_curves(count, p, curve_seed, seed_offset = 0, increment_step = 1, fixed_a = True, verify = True, r_min_bits = 160, save_to_json = True, jsonfile = "curves_json/x962-sim/curves.json", logfile = "curves_json/x962-sim/curves.log", MR = True, overwrite = False, verbosity_freq = 1000):
    assert fixed_a
    a = -3
    
    if os.path.exists(jsonfile) and not overwrite:
        print("The result file already exists! Aborting...")
        return
    
    def feedback(text, frmt = '{:s}', outfile = logfile):
        print(text, end='')
        with open(outfile, 'a') as f:
            f.write(frmt.format(text))
    with open(logfile, 'w'):
        pass
    
    seed = increment_seed(curve_seed, seed_offset)
    bits = p.nbits()
    feedback("Generating " + str(bits) + "-bit curves from the initial seed " + str(seed) + " offset by " + str(seed_offset) + "...\n")
    sim_curves = {}
    sim_curves["name"] = "x962_sim_" + str(bits)
    sim_curves["desc"] = "simulated curves generated according to the X9.62 standard using the initial seed " + str(seed) + " (the standard seed offset by " + str(seed_offset) + ")"
    sim_curves["curves_tried"] = count
    sim_curves["curves"] = []
    
    rel_seed = 0
    start_time = time.time()
    total_time = 0
    for i in [1..count]:
        rel_seed = increment_step * i
        if i%verbosity_freq == 0:
            end_time = time.time()
            diff_time = end_time - start_time
            total_time += diff_time
            feedback(str(i) + " out of " + str(count) + " curves tried, currently at seed " + str(int_to_hex_string(rel_seed)) + ", time elapsed: " + str(diff_time) + "\n")
            start_time = time.time()
        seed_i = increment_seed(seed, increment_step * i)
        r = generate_r(seed_i, p)
        b = get_b_from_r(r, p)
        if b == None:
            continue
        E = EllipticCurve(GF(p), [a,b])
        
        alright, h, n = verify_security(E, r_min_bits, MR = MR)
        if alright:
            assert h*n == E.order()
            sim_curve = {
              "name": "x962_sim_" + str(bits) + "_rel_seed_" + str(rel_seed),
              "category": sim_curves["name"],
              "desc": "",
              "field": {
                "type": "Prime",
                "p": str(hex(p)),
                "bits": bits,
              },
              "form": "Weierstrass",
              "params": {
                "a": str(hex(-3)),
                "b": str(hex(b))
              },
              "generator": None,
              "order": n,
              "cofactor": h,
              "characteristics": None,
              "seed": seed_i
            }
            sim_curves["curves"].append(sim_curve)
    
    feedback(90 * '.' + "\n" + "Finished, total time elapsed: " + str(total_time))
    sim_curves["curves_total"] = len(sim_curves["curves"])
    if save_to_json:
        save_into_json(sim_curves, jsonfile)
    return sim_curves

def generate_x962_standard_like_curves(bitlen, count, offset = 0, save_to_json = True, overwrite = False, verbosity_freq = 1000):
    #bitlens, primes and corresponding seeds, case a=-3 (curves r1, prime fields only)
    x962_params = []
    x962_params.append((112, 0xDB7C2ABF62E35E668076BEAD208B, '00F50B028E4D696E676875615175290472783FB1'))
    x962_params.append((128, 0xFFFFFFFDFFFFFFFFFFFFFFFFFFFFFFFF, '000E0D4D696E6768756151750CC03A4473D03679'))
    x962_params.append((160, 0xFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF7FFFFFFF, '1053CDE42C14D696E67687561517533BF3F83345'))
    x962_params.append((192, 0xFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFEFFFFFFFFFFFFFFFF, '3045AE6FC8422F64ED579528D38120EAE12196D5'))
    x962_params.append((224, 0xFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF000000000000000000000001, 'BD71344799D5C7FCDC45B59FA3B9AB8F6A948BC5'))
    x962_params.append((256, 0xFFFFFFFF00000001000000000000000000000000FFFFFFFFFFFFFFFFFFFFFFFF, 'C49D360886E704936A6678E1139D26B7819F7E90'))
    x962_params.append((384, 0xFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFEFFFFFFFF0000000000000000FFFFFFFF, 'A335926AA319A27A1D00896A6773A4827ACDAC73'))
    x962_params.append((521, 0x01FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF, 'D09E8800291CB85396CC6717393284AAA0DA64BA'))
    
    for bits, p, seed in x962_params:
        assert p.nbits() == bits
        assert len(seed) == 40
        if bits == bitlen:
            jsonfile = 'curves_json/x962-sim/curves' + str(bits) + '.json'
            logfile = 'curves_json/x962-sim/curves' + str(bits) + '.log'
            return generate_x962_curves(count, p, seed, offset, -1, r_min_bits = bits-10, save_to_json = save_to_json, jsonfile = jsonfile, logfile = logfile, overwrite = overwrite, verbosity_freq = verbosity_freq)

# %%
generate_x962_standard_like_curves(256, 1, offset= -163, save_to_json = False, verbosity_freq = 10)
# Out:
# Generating 256-bit curves from the initial seed C49D360886E704936A6678E1139D26B7819F7E08 offset by -136...
# 10 out of 500 curves tried, currently at seed -A, time elapsed: 6.244231462478638
# 20 out of 500 curves tried, currently at seed -14, time elapsed: 14.628513813018799
# 30 out of 500 curves tried, currently at seed -1E, time elapsed: 32.09238958358765
# 40 out of 500 curves tried, currently at seed -28, time elapsed: 12.959562301635742
# 50 out of 500 curves tried, currently at seed -32, time elapsed: 12.715399742126465
# 60 out of 500 curves tried, currently at seed -3C, time elapsed: 12.465449094772339
# 70 out of 500 curves tried, currently at seed -46, time elapsed: 14.622420072555542
# 80 out of 500 curves tried, currently at seed -50, time elapsed: 13.322563171386719
# 90 out of 500 curves tried, currently at seed -5A, time elapsed: 9.316730737686157
# 100 out of 500 curves tried, currently at seed -64, time elapsed: 12.705070972442627
# 110 out of 500 curves tried, currently at seed -6E, time elapsed: 14.489673852920532
# 120 out of 500 curves tried, currently at seed -78, time elapsed: 17.912803888320923
# 130 out of 500 curves tried, currently at seed -82, time elapsed: 10.217097997665405
# 140 out of 500 curves tried, currently at seed -8C, time elapsed: 17.130665063858032
# 150 out of 500 curves tried, currently at seed -96, time elapsed: 9.630815505981445
# 160 out of 500 curves tried, currently at seed -A0, time elapsed: 14.916394472122192
# 170 out of 500 curves tried, currently at seed -AA, time elapsed: 13.39699101448059
# 180 out of 500 curves tried, currently at seed -B4, time elapsed: 24.37934637069702
# 190 out of 500 curves tried, currently at seed -BE, time elapsed: 8.027560472488403
# 200 out of 500 curves tried, currently at seed -C8, time elapsed: 17.56275177001953
# 210 out of 500 curves tried, currently at seed -D2, time elapsed: 19.683507442474365
# 220 out of 500 curves tried, currently at seed -DC, time elapsed: 18.017916440963745
# 230 out of 500 curves tried, currently at seed -E6, time elapsed: 5.754849433898926
# 240 out of 500 curves tried, currently at seed -F0, time elapsed: 14.23281192779541
# 250 out of 500 curves tried, currently at seed -FA, time elapsed: 14.405843496322632
# 260 out of 500 curves tried, currently at seed -104, time elapsed: 18.487502098083496
# 270 out of 500 curves tried, currently at seed -10E, time elapsed: 21.65160298347473
# 280 out of 500 curves tried, currently at seed -118, time elapsed: 11.900606393814087
# 290 out of 500 curves tried, currently at seed -122, time elapsed: 11.117718696594238
# 300 out of 500 curves tried, currently at seed -12C, time elapsed: 10.309964895248413
# 310 out of 500 curves tried, currently at seed -136, time elapsed: 120.06047296524048
# 320 out of 500 curves tried, currently at seed -140, time elapsed: 6.150503158569336
# 330 out of 500 curves tried, currently at seed -14A, time elapsed: 14.15320348739624
# 340 out of 500 curves tried, currently at seed -154, time elapsed: 21.68327045440674
# 350 out of 500 curves tried, currently at seed -15E, time elapsed: 13.193578958511353
# 360 out of 500 curves tried, currently at seed -168, time elapsed: 9.668262720108032
# 370 out of 500 curves tried, currently at seed -172, time elapsed: 20.524662017822266
# 380 out of 500 curves tried, currently at seed -17C, time elapsed: 15.871676921844482
# 390 out of 500 curves tried, currently at seed -186, time elapsed: 19.3352530002594
# 400 out of 500 curves tried, currently at seed -190, time elapsed: 21.619349241256714
# 410 out of 500 curves tried, currently at seed -19A, time elapsed: 24.964269876480103
# 420 out of 500 curves tried, currently at seed -1A4, time elapsed: 17.376952171325684
# 430 out of 500 curves tried, currently at seed -1AE, time elapsed: 11.844419956207275
# 440 out of 500 curves tried, currently at seed -1B8, time elapsed: 13.710933208465576
# 450 out of 500 curves tried, currently at seed -1C2, time elapsed: 5.525228500366211
# 460 out of 500 curves tried, currently at seed -1CC, time elapsed: 13.481635093688965
# 470 out of 500 curves tried, currently at seed -1D6, time elapsed: 12.941627264022827
# 480 out of 500 curves tried, currently at seed -1E0, time elapsed: 20.845720052719116
# 490 out of 500 curves tried, currently at seed -1EA, time elapsed: 10.333168029785156
# 500 out of 500 curves tried, currently at seed -1F4, time elapsed: 16.721888780593872
# Finished, total time: 844.3048310279846
# {'name': 'x962_sim_256',
#  'desc': 'simulated curves generated according to the X9.62 standard using the initial seed C49D360886E704936A6678E1139D26B7819F7E08 (the standard seed offset by -136)',
#  'curves_tried': 500,
#  'curves': [{'name': 'x962_sim_256_rel_seed_-27',
#    'category': 'x962_sim_256',
#    'desc': '',
#    'field': {'type': 'Prime',
#     'p': '0xffffffff00000001000000000000000000000000ffffffffffffffffffffffff',
#     'bits': 256},
#    'form': 'Weierstrass',
#    'params': {'a': '-0x3',
#     'b': '0x2c4e6ff764fee8e9c6d5d5e351b89cb3d01f109bec64db591a4bdc22382f2216'},
#    'generator': None,
#    'order': 115792089210356248762697446949407573530228464814316900086834038452915778174553,
#    'cofactor': None,
#    'characteristics': None,
#    'seed': 'C49D360886E704936A6678E1139D26B7819F7DED'},
#   {'name': 'x962_sim_256_rel_seed_-78',
#    'category': 'x962_sim_256',
#    'desc': '',
#    'field': {'type': 'Prime',
#     'p': '0xffffffff00000001000000000000000000000000ffffffffffffffffffffffff',
#     'bits': 256},
#    'form': 'Weierstrass',
#    'params': {'a': '-0x3',
#     'b': '0x3af5540d129a5ecfedda59fc3f6e3a5982f4c9ee42f8540a188b5c3804d4693d'},
#    'generator': None,
#    'order': 115792089210356248762697446949407573530303234821994790496752841769725713723975,
#    'cofactor': None,
#    'characteristics': None,
#    'seed': 'C49D360886E704936A6678E1139D26B7819F7DBA'},
#   {'name': 'x962_sim_256_rel_seed_-263',
#    'category': 'x962_sim_256',
#    'desc': '',
#    'field': {'type': 'Prime',
#     'p': '0xffffffff00000001000000000000000000000000ffffffffffffffffffffffff',
#     'bits': 256},
#    'form': 'Weierstrass',
#    'params': {'a': '-0x3',
#     'b': '0x4de31088f2e35eaf2480d0b304f894fc0d9b9f3cba425530374e01bbb4c61ebe'},
#    'generator': None,
#    'order': 115792089210356248762697446949407573529966255779142916210593585512232065503070,
#    'cofactor': None,
#    'characteristics': None,
#    'seed': 'C49D360886E704936A6678E1139D26B7819F7D01'},
#   {'name': 'x962_sim_256_rel_seed_-302',
#    'category': 'x962_sim_256',
#    'desc': '',
#    'field': {'type': 'Prime',
#     'p': '0xffffffff00000001000000000000000000000000ffffffffffffffffffffffff',
#     'bits': 256},
#    'form': 'Weierstrass',
#    'params': {'a': '-0x3',
#     'b': '0x19d11d62a20b2fd6104577092c7039e49c91d18440dabacf7fdb3ba849c8232c'},
#    'generator': None,
#    'order': 115792089210356248762697446949407573529750804498397016832131724043724637417210,
#    'cofactor': None,
#    'characteristics': None,
#    'seed': 'C49D360886E704936A6678E1139D26B7819F7CDA'},
#   {'name': 'x962_sim_256_rel_seed_-336',
#    'category': 'x962_sim_256',
#    'desc': '',
#    'field': {'type': 'Prime',
#     'p': '0xffffffff00000001000000000000000000000000ffffffffffffffffffffffff',
#     'bits': 256},
#    'form': 'Weierstrass',
#    'params': {'a': '-0x3',
#     'b': '0x2cb154d92840d48440bb1d5b69066c7f868ae92174c3fe52259b759a125afadc'},
#    'generator': None,
#    'order': 115792089210356248762697446949407573529613738060483619135601151883315713287884,
#    'cofactor': None,
#    'characteristics': None,
#    'seed': 'C49D360886E704936A6678E1139D26B7819F7CB8'},
#   {'name': 'x962_sim_256_rel_seed_-414',
#    'category': 'x962_sim_256',
#    'desc': '',
#    'field': {'type': 'Prime',
#     'p': '0xffffffff00000001000000000000000000000000ffffffffffffffffffffffff',
#     'bits': 256},
#    'form': 'Weierstrass',
#    'params': {'a': '-0x3',
#     'b': '0x1de431b8193448be5b15e319f0a884786f0652b6277d266ce27a4c091c52402e'},
#    'generator': None,
#    'order': 115792089210356248762697446949407573530592366778265145909076119741458448058857,
#    'cofactor': None,
#    'characteristics': None,
#    'seed': 'C49D360886E704936A6678E1139D26B7819F7C6A'}],
#  'curves_total': 6}

# %%
generate_x962_standard_like_curves(256, 1, offset= -162, save_to_json = False, verbosity_freq = 10)
# Out:
# Generating 256-bit curves from the initial seed C49D360886E704936A6678E1139D26B7819F7DEE offset by -162...
# 9 12865787690039583195855271883267508170025384979368544454092670939212864241617
# ..........................................................................................
# Finished, total time elapsed: 0
# {'name': 'x962_sim_256',
#  'desc': 'simulated curves generated according to the X9.62 standard using the initial seed C49D360886E704936A6678E1139D26B7819F7DEE (the standard seed offset by -162)',
#  'curves_tried': 1,
#  'curves': [{'name': 'x962_sim_256_rel_seed_-1',
#    'category': 'x962_sim_256',
#    'desc': '',
#    'field': {'type': 'Prime',
#     'p': '0xffffffff00000001000000000000000000000000ffffffffffffffffffffffff',
#     'bits': 256},
#    'form': 'Weierstrass',
#    'params': {'a': '-0x3',
#     'b': '0x2c4e6ff764fee8e9c6d5d5e351b89cb3d01f109bec64db591a4bdc22382f2216'},
#    'generator': None,
#    'order': 12865787690039583195855271883267508170025384979368544454092670939212864241617,
#    'cofactor': 9,
#    'characteristics': None,
#    'seed': 'C49D360886E704936A6678E1139D26B7819F7DED'}],
#  'curves_total': 1}
