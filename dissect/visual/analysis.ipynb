# %% [markdown]
# # Visual analysis of trait results

# %% [markdown]
# ## Data loading & filtering

# %%
# Please contact the people at CRoCS if you think you should have access to the database
USERNAME = "YOUR USERNAME"
PASSWORD = "YOUR DATABASE PASSWORD"

db = connect(f"mongodb://{USERNAME}:{PASSWORD}@dissect.crocs.fi.muni.cz:27017/dissect?tls=true")

# %%
from dissect.utils.data_processing import load_curves, get_trait_df
from dissect.visual.widgets import trait_selection_widget, get_filtering_widgets, get_choices
from dissect.visual.visualization import interact_multiplot
curves = load_curves()
ts = trait_selection_widget()

# %%
trait_name = ts.value[:3]
trait_df = get_trait_df(curves, trait_name)
filtering_widgets = get_filtering_widgets(trait_name, trait_df)
# Out:
# Loading trait results:   0%|          | 0/1303632 [00:00<?, ?it/s]
# Tab(children=(HBox(children=(VBox(children=(Label(value='source:'), Text(value='', layout=Layout(width='auto')…

# %% [markdown]
# ## Data visualization

# %%
results = interact_multiplot(trait_df,filtering_widgets, tick_spacing = 0,columns = 1)
# Out:
# HBox(children=(IntSlider(value=10, description='height', max=30, min=1), IntSlider(value=7, description='width…
# Output()

# %% [markdown]
# ## Data inspection

# %%
results
# Out:
#       curve  simulated  bitlength  field cofactor  k  \
# 310   P-192      False        192  Prime        1  1
# 311   P-192      False        192  Prime        1  2
# 312   P-192      False        192  Prime        1  3
# 410   P-224      False        224  Prime        1  1
# 411   P-224      False        224  Prime        1  2
# 412   P-224      False        224  Prime        1  3
# 710   P-256      False        256  Prime        1  1
# 711   P-256      False        256  Prime        1  2
# 712   P-256      False        256  Prime        1  3
# 940   P-384      False        384  Prime        1  1
# 941   P-384      False        384  Prime        1  2
# 942   P-384      False        384  Prime        1  3
# 1140  P-521      False        521  Prime        1  1
# 1141  P-521      False        521  Prime        1  2
# 1142  P-521      False        521  Prime        1  3
#
#                                                      Hx  bits  difference  \
# 310   6020462823756886567582134805875261119166989766...   189           3
# 311   3022657313421880686711133267553559097318421761...   191           1
# 312   3692530618244383155080174265579867192260117753...   192           0
# 410   1927792911356629307111030803469948802683193421...   224           0
# 411   2442679549853369003134216989894741920849366402...   224           0
# 412   6989898447131181847189751323798131160269458592...   223           1
# 710   4843956129390645175905258525279791420276294952...   255           1
# 711   1943924079585421650416687835208048085202504807...   254           2
# 712   3685863151572957742761802158718166575442697597...   255           1
# 940   2624703509579968926862315674456698189185292349...   384           0
# 941   3254316561548109186186336208488320966399922574...   384           0
# 942   4037826823510576517606781535995257931969844421...   378           6
# 1140  2661740802050217063228768716723360960729859168...   520           1
# 1141  1664019621786085728782817326152282335971438675...   519           2
# 1142  2635255411859233464817797895169623809343286513...   520           1
#
#         ratio
# 310   0.98438
# 311   0.99479
# 312       1.0
# 410       1.0
# 411       1.0
# 412   0.99554
# 710   0.99609
# 711   0.99219
# 712   0.99609
# 940       1.0
# 941       1.0
# 942   0.98438
# 1140  0.99808
# 1141  0.99616
# 1142  0.99808

# %%
trait_df
# Out:
#                                  curve  simulated  bitlength  field cofactor  \
# 0       x962_sim_128_seed_diff_2896470       True        128  Prime        1
# 1       x962_sim_128_seed_diff_2896470       True        128  Prime        1
# 2       x962_sim_128_seed_diff_3811712       True        128  Prime        1
# 3       x962_sim_128_seed_diff_3811712       True        128  Prime        1
# 4       x962_sim_128_seed_diff_3560709       True        128  Prime        1
# ...                                ...        ...        ...    ...      ...
# 108519  x962_sim_256_seed_diff_4448114       True        256  Prime        1
# 108520  x962_sim_256_seed_diff_4314713       True        256  Prime        1
# 108521  x962_sim_256_seed_diff_4314713       True        256  Prime        1
# 108522  x962_sim_256_seed_diff_4651163       True        256  Prime        1
# 108523  x962_sim_256_seed_diff_4651163       True        256  Prime        1
#
#         deg                                  twist_cardinality  \
# 0         1            340282366762482138470468292964371595469
# 1         2  1157920891294764087800768327715665705604424427...
# 2         1            340282366762482138463252537796455997459
# 3         2  1157920891294764087800768327715665705599804254...
# 4         1            340282366762482138458105995371147958067
# ...     ...                                                ...
# 108519    2  1340780792369910000112255670799101168355979935...
# 108520    1  1157920892103562487626974469494075735296983254...
# 108521    2  1340780792369910000112255670799101168355979935...
# 108522    1  1157920892103562487626974469494075735295104447...
# 108523    2  1340780792369910000112255670799101168355979935...
#
#                                             factorization
# 0       [463, 30495497, 1246951859, 19327382918923983881]
# 1                                     NO DATA (timed out)
# 2               [340282366762482138463252537796455997459]
# 3       [3, 3, 3, 3, 142953196456143714543304731816748...
# 4          [4483, 58498981077619, 1297544927469108488171]
# ...                                                   ...
# 108519                                NO DATA (timed out)
# 108520  [3, 43, 701420047, 43432057211, 9102358869349,...
# 108521                                NO DATA (timed out)
# 108522  [3, 3, 311, 264220889, 15657010468589837981353...
# 108523                                NO DATA (timed out)
#
# [108524 rows x 8 columns]

# %%
curves
# Out:
#                                  curve  simulated  bitlength   field cofactor
# 0               wap-wsg-idm-ecid-wtls1      False        113  Binary        2
# 1               wap-wsg-idm-ecid-wtls3      False        163  Binary        2
# 2               wap-wsg-idm-ecid-wtls4      False        113  Binary        2
# 3               wap-wsg-idm-ecid-wtls5      False        163  Binary        2
# 4               wap-wsg-idm-ecid-wtls6      False        112   Prime        1
# ...                                ...        ...        ...     ...      ...
# 217391  x962_sim_256_seed_diff_4998208       True        256   Prime       29
# 217392  x962_sim_256_seed_diff_4998860       True        256   Prime        1
# 217393  x962_sim_256_seed_diff_4999137       True        256   Prime       31
# 217394  x962_sim_256_seed_diff_4999772       True        256   Prime        1
# 217395  x962_sim_256_seed_diff_4999961       True        256   Prime       13
#
# [217396 rows x 5 columns]

# %% [markdown]
# ## Playground
