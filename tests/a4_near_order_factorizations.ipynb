# %%
load("../curve_handler.sage")
load("testing.sage")

# %%
def attempt_factor(n, t):
    try:
        factorization = timeout(ecm.factor, [n], timeout_duration = t)
    except:
        factorization = None
    return factorization

def near_order_factorizations(n, sign = '+', k_max = 10, t = 10):
    factorizations = []
    assert sign in ['+', '-']
    for k in [1..k_max]:
        if sign == '+':
            m = k * n + 1
        elif sign == '-':
            m = k * n - 1
        try:
            factorizations.append(attempt_factor(m, t))
        except:
            continue
    return factorizations

def largest_factor_bitlen(factorization):
    try:
        bitlen = factorization[-1].nbits()
    except:
        bitlen = '-'
    return bitlen

def get_curve_results(curve, k_max, t):
    curve_results = {'plus': {}, 'minus': {}}
    curve_results['plus']['factorizations'] = near_order_factorizations(curve.order, '+', k_max, t)
    curve_results['plus']['largest_factor_bitlens'] = list(map(largest_factor_bitlen, curve_results['plus']['factorizations']))
    curve_results['plus']['min_largest_factor_bitlen'] = min(remove_values_from_list(curve_results['plus']['largest_factor_bitlens'],'-'))
    curve_results['minus']['factorizations'] = near_order_factorizations(curve.order, '-', k_max, t)
    curve_results['minus']['largest_factor_bitlens'] = list(map(largest_factor_bitlen, curve_results['minus']['factorizations']))
    curve_results['minus']['min_largest_factor_bitlen'] = min(remove_values_from_list(curve_results['minus']['largest_factor_bitlens'],'-'))
    return curve_results

def compute_a4_results(k_max = 10, t = 10, order_bound = 256, overwrite = False):
    parameters = {'k_max': k_max, 't': t}
    compute_results('test', parameters, order_bound = order_bound, overwrite = overwrite)
        
def pretty_print_a4_results(save_to_txt = True):
    pretty_print_results('a4', [['plus','largest_factor_bitlens'], ['minus', 'largest_factor_bitlens']], ['largest_factor_bitlens (+)', 'largest_factor_bitlens (-)'], res_sort_key = ints_before_strings, save_to_txt = save_to_txt)

# %%
compute_a4_results(order_bound = 256)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-67adedfbeb44> in <module>()
# ----> 1 compute_a4_results(curve_db, k_max = Integer(10), t = Integer(15), order_bound = Integer(256))
#
# TypeError: compute_a4_results() got multiple values for argument 'k_max'

# %%
pretty_print_a4_results(save_to_txt = False)
# Out:
# +-----------+-------+
# | parameter | value |
# +-----------+-------+
# |   k_max   |   10  |
# |  timeout  |   15  |
# +-----------+-------+
#
#
# +-----------------+------+----------------------------------------------------+----------------------------------------------------+
# |       name      | bits |             largest_factor_bitlens (+)             |             largest_factor_bitlens (-)             |
# +-----------------+------+----------------------------------------------------+----------------------------------------------------+
# |    secp112r2    | 110  |     [49, 55, 61, 75, 76, 83, 84, 88, 99, 107]      |     [39, 42, 43, 58, 59, 60, 63, 68, 77, '-']      |
# |    secp112r1    | 112  |     [44, 46, 52, 56, 77, 84, 88, 89, 108, 113]     |     [54, 78, 81, 90, 92, 93, 94, 94, 95, 100]      |
# |    secp128r2    | 126  |    [36, 40, 71, 72, 81, 82, 89, 104, 109, 110]     |    [35, 48, 54, 57, 66, 81, 95, 103, 104, 108]     |
# |    secp128r1    | 128  |     [46, 49, 56, 59, 69, 71, 79, 91, 114, 130]     |     [48, 53, 56, 57, 57, 68, 92, 93, 121, 130]     |
# |       mnt1      | 156  |   [62, 63, 84, 95, 107, 114, 119, 120, 123, 153]   |   [57, 67, 71, 84, 94, 104, 107, 113, 120, '-']    |
# |      bn158      | 158  |    [36, 60, 68, 69, 89, 94, 105, 107, 140, 158]    |   [68, 84, 84, 98, 116, 119, 126, 132, 147, 154]   |
# |    secp256k1    | 256  | [113, 121, 128, 185, 194, 205, 211, 224, '-', '-'] | [109, 126, 137, 149, 170, 179, 199, '-', '-', '-'] |
# |    secp256r1    | 256  | [98, 148, 149, 167, 192, 203, 215, '-', '-', '-']  | [92, 167, 174, 180, 185, 196, 254, '-', '-', '-']  |
# |      K-283      | 281  |                    Not computed                    |                    Not computed                    |
# |    sect283k1    | 281  |                    Not computed                    |                    Not computed                    |
# |      B-283      | 282  |                    Not computed                    |                    Not computed                    |
# |    sect283r1    | 282  |                    Not computed                    |                    Not computed                    |
# |      bn286      | 286  |                    Not computed                    |                    Not computed                    |
# |    BLS12-446    | 299  |                    Not computed                    |                    Not computed                    |
# |    BLS12-455    | 305  |                    Not computed                    |                    Not computed                    |
# |      bn318      | 318  |                    Not computed                    |                    Not computed                    |
# | brainpoolP320r1 | 320  |                    Not computed                    |                    Not computed                    |
# | brainpoolP320t1 | 320  |                    Not computed                    |                    Not computed                    |
# |      bn350      | 350  |                    Not computed                    |                    Not computed                    |
# |    Curve67254   | 380  |                    Not computed                    |                    Not computed                    |
# |      M-383      | 381  |                    Not computed                    |                    Not computed                    |
# |      bn382      | 382  |                    Not computed                    |                    Not computed                    |
# |    BLS24-477    | 383  |                    Not computed                    |                    Not computed                    |
# |     Fp384BN     | 384  |                    Not computed                    |                    Not computed                    |
# |      P-384      | 384  |                    Not computed                    |                    Not computed                    |
# | brainpoolP384r1 | 384  |                    Not computed                    |                    Not computed                    |
# | brainpoolP384t1 | 384  |                    Not computed                    |                    Not computed                    |
# |    secp384r1    | 384  |                    Not computed                    |                    Not computed                    |
# |      K-409      | 407  |                    Not computed                    |                    Not computed                    |
# |    sect409k1    | 407  |                    Not computed                    |                    Not computed                    |
# |      B-409      | 409  |                    Not computed                    |                    Not computed                    |
# |    sect409r1    | 409  |                    Not computed                    |                    Not computed                    |
# |      bn414      | 414  |                    Not computed                    |                    Not computed                    |
# |    BLS12-638    | 427  |                    Not computed                    |                    Not computed                    |
# |      Ed448      | 446  |                    Not computed                    |                    Not computed                    |
# |      bn446      | 446  |                    Not computed                    |                    Not computed                    |
# |      bn478      | 478  |                    Not computed                    |                    Not computed                    |
# |      M-511      | 509  |                    Not computed                    |                    Not computed                    |
# |      bn510      | 510  |                    Not computed                    |                    Not computed                    |
# |     gost512     | 511  |                    Not computed                    |                    Not computed                    |
# |     Fp512BN     | 512  |                    Not computed                    |                    Not computed                    |
# | brainpoolP512r1 | 512  |                    Not computed                    |                    Not computed                    |
# | brainpoolP512t1 | 512  |                    Not computed                    |                    Not computed                    |
# |      P-521      | 521  |                    Not computed                    |                    Not computed                    |
# |    secp521r1    | 521  |                    Not computed                    |                    Not computed                    |
# |      bn542      | 542  |                    Not computed                    |                    Not computed                    |
# |      B-571      | 570  |                    Not computed                    |                    Not computed                    |
# |      K-571      | 570  |                    Not computed                    |                    Not computed                    |
# |    sect571k1    | 570  |                    Not computed                    |                    Not computed                    |
# |    sect571r1    | 570  |                    Not computed                    |                    Not computed                    |
# |      bn574      | 574  |                    Not computed                    |                    Not computed                    |
# |      bn606      | 606  |                    Not computed                    |                    Not computed                    |
# |      bn638      | 638  |                    Not computed                    |                    Not computed                    |
# +-----------------+------+----------------------------------------------------+----------------------------------------------------+
